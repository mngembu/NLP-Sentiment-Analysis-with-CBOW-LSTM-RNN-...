# %% [markdown]
# # Stock News Sentiment Analysis with ML - NLP BoW

# %% [markdown]
# This notebook focuses on predicting whether stock prices will increase or decrease based on sentimental analysis of news headlines. In this study I will use data available on Kaggle https://www.kaggle.com/datasets/avisheksood/stock-news-sentiment-analysismassive-dataset?select=Sentiment_Stock_data.csv.
# This is a huge dataset with 108,301 unique values, so I will only use a sample of 5000 observations.

# %% [markdown]
# We are going to solve the classificaion problem using Natural Language Processing with the following steps:
# - Text preprocessing applying tokenization, stopwords, lemmatization
# - Converting text to vectors using Bag of Words
# - Training a RandomForest classifier
# - Measuring the model performance on the test data
#
# We will use Python and ML

# %% [markdown]
# ### Importing the libraries

# %%
import pandas as pd
import numpy as np

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.9.1'

# %%
import nltk
import re
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
nltk.download('all')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package bllip_wsj_no_aux is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cess_cat is already up-to-date!
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cess_esp is already up-to-date!
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package comparative_sentences is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package comtrans is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2007 is already up-to-date!
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package crubadan is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package dolch to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package dolch is already up-to-date!
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package europarl_raw is already up-to-date!
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package extended_omw is already up-to-date!
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package floresta is already up-to-date!
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package framenet_v15 is already up-to-date!
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package framenet_v17 is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package indian is already up-to-date!
# [nltk_data]    | Downloading package jeita to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package jeita is already up-to-date!
# [nltk_data]    | Downloading package kimmo to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package kimmo is already up-to-date!
# [nltk_data]    | Downloading package knbc to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package knbc is already up-to-date!
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package large_grammars is already up-to-date!
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package lin_thesaurus is already up-to-date!
# [nltk_data]    | Downloading package mac_morpho to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mac_morpho is already up-to-date!
# [nltk_data]    | Downloading package machado to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package machado is already up-to-date!
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package masc_tagged is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package moses_sample is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package mte_teip5 to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mte_teip5 is already up-to-date!
# [nltk_data]    | Downloading package mwa_ppdb to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mwa_ppdb is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nombank.1.0 is already up-to-date!
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nonbreaking_prefixes is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package opinion_lexicon is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package paradigms to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package paradigms is already up-to-date!
# [nltk_data]    | Downloading package pe08 to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pe08 is already up-to-date!
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package perluniprops is already up-to-date!
# [nltk_data]    | Downloading package pil to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pil is already up-to-date!
# [nltk_data]    | Downloading package pl196x to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pl196x is already up-to-date!
# [nltk_data]    | Downloading package porter_test to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package porter_test is already up-to-date!
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package problem_reports is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package product_reviews_1 is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package product_reviews_2 is already up-to-date!
# [nltk_data]    | Downloading package propbank to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package propbank is already up-to-date!
# [nltk_data]    | Downloading package pros_cons to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pros_cons is already up-to-date!
# [nltk_data]    | Downloading package ptb to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ptb is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package qc to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package qc is already up-to-date!
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package rslp to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package rslp is already up-to-date!
# [nltk_data]    | Downloading package rte to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package rte is already up-to-date!
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sample_grammars is already up-to-date!
# [nltk_data]    | Downloading package semcor to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package semcor is already up-to-date!
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sentence_polarity is already up-to-date!
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sentiwordnet is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sinica_treebank is already up-to-date!
# [nltk_data]    | Downloading package smultron to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package smultron is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package spanish_grammars is already up-to-date!
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package subjectivity is already up-to-date!
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package switchboard is already up-to-date!
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package udhr to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package universal_treebanks_v20 is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package vader_lexicon is already up-to-date!
# [nltk_data]    | Downloading package verbnet to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package verbnet is already up-to-date!
# [nltk_data]    | Downloading package verbnet3 to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package verbnet3 is already up-to-date!
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wmt15_eval to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wmt15_eval is already up-to-date!
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package word2vec_sample is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to
# [nltk_data]    |     C:\Users\mngembu\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ycoe is already up-to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
#from nltk import sent_tokenize
#from gensim.utils import simple_preprocess

# %% [markdown]
# ### Importing and preprocessing the data

# %%
df = pd.read_csv('Sentiment_Stock_data.csv')
df = df.head(5000)

# %%
df.head()
# Out:
#    Unnamed: 0  Sentiment                                           Sentence
# 0           0          0  According to Gran , the company has no plans t...
# 1           1          1  For the last quarter of 2010 , Componenta 's n...
# 2           2          1  In the third quarter of 2010 , net sales incre...
# 3           3          1  Operating profit rose to EUR 13.1 mn from EUR ...
# 4           4          1  Operating profit totalled EUR 21.1 mn , up fro...

# %%
df = df[['Sentiment', 'Sentence']]

# %%
df.shape
# Out:
# (5000, 2)

# %%
df.isnull().sum()
# Out:
# Sentiment    0
# Sentence     0
# dtype: int64

# %%
# Dropping null values

df.dropna(inplace=True)

# %%
df.reset_index(inplace=True)

# %%
# specifying the independent and dependent features
X = df['Sentence']
y = df['Sentiment']

# %%
# copying X for preprocessing

sentences = X.copy()

# %%
# Lemmatization to convert words in sentences to their meaningful root

from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()

corpus = []
for i in range(0, len(sentences)):
    text = re.sub('[^a-zA-Z]', ' ', sentences[i])
    text = text.lower()
    text = text.split()
    all_stopwords = stopwords.words('english')
    all_stopwords.remove('not')
    all_stopwords.remove('no')
    
    text = [lemmatizer.lemmatize(word) for word in text if not word in set(all_stopwords)]
    text = ' '.join(text)
    corpus.append(text)

# %%
corpus[0]
# Out:
# 'according gran company no plan move production russia although company growing'

# %%
len(corpus)
# Out:
# 5000

# %%
corpus
# Out:
# ['according gran company no plan move production russia although company growing',
#  'last quarter componenta net sale doubled eur eur period year earlier moved zero pre tax profit pre tax loss eur',
#  'third quarter net sale increased eur mn operating profit eur mn',
#  'operating profit rose eur mn eur mn corresponding period representing net sale',
#  'operating profit totalled eur mn eur mn representing net sale',
#  'finnish talentum report operating profit increased eur mn eur mn net sale totaled eur mn eur mn',
#  'clothing retail chain sepp l sale increased eur mn operating profit rose eur mn eur mn',
#  'consolidated net sale increased reach eur operating profit amounted eur compared loss eur prior year period',
#  'foundry division report sale increased eur mn eur mn corresponding period sale machine shop division increased eur mn eur mn corresponding period',
#  'helsinki afx share closed higher led nokia announced plan team sanyo manufacture g handset nokian tyre fourth quarter earnings report beat analyst expectation dealer said',
#  'board director propose dividend eur per share eur per share paid',
#  'megafon subscriber base increased million user december market share number customer amounted late late according teliasonera estimate',
#  'net income life insurance doubled eur mn eur mn net income non life insurance rose eur mn eur mn corresponding period',
#  'net sale surged eur teleste said eur sale came acquisition made',
#  'nordea group operating profit increased percent year year billion euro total revenue percent billion euro',
#  'operating profit nine month period increased eur net sale increased eur compared corresponding period',
#  'operating profit three month period increased eur revenue increased eur compared corresponding period',
#  'company net profit rose year million euro sale million euro year company said earlier',
#  'lithuanian beer market made million liter january rise percent year earlier figure lithuanian brewer association reporting citing result member',
#  'viking line cargo revenue increased eur mn cargo volume increased cargo unit',
#  'fair value property portfolio doubled result kapiteeli acquisition totalled eur million',
#  'february finnish medium company sanoma oyj hel saa v said yesterday net profit almost tripled eur eur announced proposal raised payout',
#  'helsinki eliiv today reported eps eur increase eps eur',
#  'commission income increased eur mn lending volume rose',
#  'january traffic measured revenue passenger kilometre rpk went capacity measured available seat kilometre ask rose',
#  'january september fiskars net profit went year year eur million net sale eur million eur million',
#  'net income life insurance rose eur mn eur mn net income non life insurance eur mn eur mn',
#  'sale risen export market',
#  'sale increased due growing market rate increased operation',
#  'agreement strengthens long term partnership nokia siemens network',
#  'company order book stood bln euro bln september pct year international order amounting mln euro mln',
#  'company said paper demand increased main market including publication paper increased average paper price percent compared last year',
#  'world second largest stainless steel maker said net profit three month period dec surged euro million u million euro u per share euro million euro per share previous year',
#  'share standard chartered stan rose ftse royal bank scotland rb share rose barclays share barc bcs',
#  'share nokia corp rose thursday cell phone maker said third quarter earnings almost doubled share global handset market increased',
#  'financial report published friday seb said net profit soared sek bn year earlier sek bn proposed dividend increase sek per share',
#  'request finnish medium company alma medium newspaper research manager jari kaivo oja finland future research centre turku school economics drawn future scenario finland national economy using model developed university denver',
#  'stock exchange announcement july basware share subscription warrant increase share capital total share subscribed basware warrant program',
#  'maximum new share subscribed exercising b option stock option plan',
#  'tiimari operates store six country including core finnish market generated turnover mln eur',
#  'acquisition considerably increase kemira sale market position russian metal industry coating market',
#  'january september finnlines net sale rose eur mn eur mn corresponding period',
#  'adjusted change group structure division net sale increased',
#  'february finnish broadband data communication system provider teleste oyj hel tlt v saw net profit jump eur last quarter eur period',
#  'finnish aktia group operating profit rose eur mn first quarter eur mn first quarter',
#  'finnish bank land consolidated net operating profit increased eur mn first quarter eur mn first quarter',
#  'finnish financial group aktia report operating profit eur mn january september eur mn corresponding period',
#  'finnish high technology provider vaahto group report net sale eur mn accounting period september february increase year earlier',
#  'net sale finnish food industry company l nnen tehtaat continuing operation increased eur mn eur mn',
#  'biohit already service many current genesis customer customer base expected expand result agreement',
#  'operating profit turnover three month period increased respectively eur eur compared corresponding period',
#  'circulation revenue increased finland sweden',
#  'clothing chain sepp l net sale increased eur mn',
#  'construction volume meanwhile grow rate percent annually',
#  'however biohit estimate total net sale continue grow favourable trend net sale lead profit',
#  'fiskars cash flow operating activity amounted eur eur previous year',
#  'lithuania operating profit rose eur eur corresponding period',
#  'fourth quarter net sale increased eur mn eur mn fourth quarter',
#  'international sale rose eur mn',
#  'net sale grew period x ac million u million x ac million',
#  'net sale increased eur april june eur year earlier',
#  'net sale rose year year eur number charger delivered went million piece',
#  'net sale totaled eur mn eur mn corresponding period',
#  'operating profit increased eur mn eur mn',
#  'operating profit margin increased',
#  'operating profit rose eur mn eur mn corresponding period',
#  'operating profit rose eur mn eur mn fourth quarter',
#  'operating profit eur mn eur mn',
#  'ramirent net sale second quarterended june euro million u million percent increase compared euro million thesecond quarter last year',
#  'revenue grew percent x ac million million x ac million',
#  'ruukki delivery volume selling price showed favourable development company comparable net sale grew year year eur ceo sakari tamminen said',
#  'company consolidated operating profit amounted eur mn eur mn year year',
#  'department store division reported increase sale per cent',
#  'fair value company investment property grew eur billion end march eur million year ago',
#  'last quarter best quarter net sale operating margin rose',
#  'major brewery increased domestic beer sale per cent last year million litre million litre',
#  'operating profit rose eur million',
#  'october finnish fishing tackle company rapala vmc corp hel rap v said today net profit rose eur first nine month eur period year earlier',
#  'according finnish metso mineral value company order gone eur bn month',
#  'finnish bank land report operating profit rose eur mn second quarter eur mn corresponding period',
#  'finnish financial group aktia operating profit increased eur mn eur mn',
#  'finnish forest machinery manufacturer ponsse net sale grew eur mn first quarter eur mn corresponding period',
#  'finnish kci konecranes raised net sale growth estimate',
#  'according hkscan finland plan increase j rvi suomen portti net sale eur mn eur mn',
#  'advertising circulation revenue grew respectively',
#  'end march group order book eur mn corresponding period',
#  'time profit company increased h reached l',
#  'operating profit net sale month period increased respectively eur eur compared financial year',
#  'operating profit net sale month period increased respectively eur eur compared financial year',
#  'operating profit net sale month period increased respectively eur eur compared',
#  'operating profit net sale month period increased respectively eur eur compared',
#  'operating profit net sale nine month period increased respectively compared corresponding period',
#  'operating profit net sale six month period increased respectively eur eur compared corresponding period',
#  'operating profit net sale six month period increased respectively eur eur compared corresponding period',
#  'operating profit net sale six month period increased respectively eur eur compared corresponding period',
#  'operating profit net sale six month period increased respectively eur eur compared corresponding period',
#  'operating profit net sale three month period increased respectively eur eur compared corresponding period',
#  'operating profit net sale three month period increased respectively eur eur compared corresponding quarter',
#  'operating profit sale three month period increased respectively eur eur compared corresponding period',
#  'operating profit turnover nine month period increased respectively eur eur compared corresponding period year ago',
#  'operating profit turnover six month period increased respectively eur eur compared corresponding period',
#  'operating profit turnover six month period increased respectively eur eur compared corresponding period year ago',
#  'cargo volume increased approximately',
#  'comparable operating profit totaled eur mn eur mn',
#  'digia said consolidated net sale january june eur period eur',
#  'diluted earnings per share eps rose eur eur',
#  'diluted earnings per share eps rose eur versus eur',
#  'diluted earnings per share eps rose eur eur',
#  'diluted earnings per share eps rose eur eur',
#  'diluted eps rose eur eur',
#  'ebit margin',
#  'eps continuing operation came eur',
#  'equity ratio compared third quarter net sale frozen food business totaled eur third quarter',
#  'eur q may finnish textile clothing design company marimekko oyj hel mmo v said today net profit rose eur first quarter eur corresponding period year earlier',
#  'finland based elcoteq se privately held provider electronics manufacturing service communication company said thursday signed long term manufacturing supply deal communication equipment company andrew corp',
#  'finnish cutlery hand tool maker fiskars oyj abp hel fisa said today net profit rose eur million usd third quarter eur million year earlier',
#  'finnish department store chain stockmann oyj abp net profit rose mln euro mln first nine month mln euro mln period',
#  'finnish lifting equipment maker konecranes oyj said july net profit rose mln euro mln first half mln euro mln period',
#  'finnish metal industry solution supplier outotec oyj net profit rose mln euro mln first nine month mln euro mln period',
#  'finnish metal product company componenta oyj net profit rose mln euro mln first quarter mln euro mln period',
#  'finnish office supply computer accessory dealer beltton group plc said net profit rose mln euro mln mln euro mln',
#  'finnish security privacy software solution developer stonesoft oyj said january preliminary sale stonegate product grew pct year year mln euro mln fourth quarter',
#  'finnish silicon wafer technology company okmetic oyj omx helsinki okm v reported thursday august operating profit eur period january june eur corresponding period',
#  'finnish software developer done solution oyj said net profit increased mln euro mln mln euro mln',
#  'first quarter underlying operating profit rose mln eur mln year earlier',
#  'first nine month company net profit rose eur eur corresponding period',
#  'helsinki afx retail wholesale group kesko reported net sale mln eur february increase pct year year',
#  'however net sale seen grown eur eur',
#  'however sale returned growth april june ceo pekka eloholma said',
#  'ragutis controlled finnish brewery reported per cent rise beer sale million litre held per cent market share',
#  'svyturys utenos alus controlled nordic group baltic beverage holding bbh posted per cent growth beer sale january may million litre',
#  'december alone member lithuanian brewer association sold total million liter beer increase percent sale million liter december',
#  'january september group net interest income increased eur mn eur mn january september',
#  'q bank land net interest income increased eur mn eur mn',
#  'sweden operating profit period review totaled eur mn corresponding period',
#  'fourth quarter orion net profit went year year eur',
#  'second quarter group net profit rose eur million eur million april june',
#  'second quarter group net profit rose eur eur april june',
#  'third quarter net sale increased year year eur million comparable currency rate growth',
#  'third quarter net sale increased year year eur comparable currency rate growth',
#  'market share widened percent percent year earlier',
#  'kesko agro eesti retailer wholesaler grain agricultural warehousing machinery accessory net sale million euro increase one tenth preceding year',
#  'kesko car import retailing business vv auto saw sale grow pct',
#  'kone net sale rose year year first nine month',
#  'adp news feb finnish management software solution provider ixonos oyj hel xns v said today net profit rose eur million usd eur million',
#  'adp news feb finnish solution provider affecto oyj hel afe v said today net profit rose eur million usd eur million',
#  'adp news feb finnish fishing tackle company rapala vmc corp hel rap v said today net profit rose eur million usd eur million',
#  'metso expects net sale increase comparable exchange rate',
#  'net interest income increased eur mn eur mn',
#  'net interest income eur mn eur mn',
#  'net interest income eur mn eur mn',
#  'net sale vegetable oil business rose eur mn eur mn',
#  'nokia multimedia net sale totaled eur bn corresponding period',
#  'operating income rose eur mn eur mn',
#  'operating profit kauppalehti group rose eur mn eur mn marketplace eur mn eur mn third quarter',
#  'operating profit rose eur mn eur mn',
#  'operating profit rose mln eur mln',
#  'operating profit rose eur mn eur mn corresponding period',
#  'operating profit rose eur mn eur corresponding period',
#  'operating profit rose eur mn eur mn corresponding period',
#  'operating profit rose eur mn eur mn corresponding period',
#  'operating profit rose eur mn eur mn',
#  'operating profit rose eur mn eur mn corresponding period',
#  'operating profit rose eur mn eur mn',
#  'operating profit rose eur mn eur mn',
#  'operating profit rose eur mn eur mn corresponding period',
#  'operating profit rose eur eur year earlier',
#  'operating profit surged eur eur',
#  'operating profit totaled eur mn slightly eur mn corresponding period',
#  'operating profit totaled eur mn eur mn',
#  'operating profit eur mn eur mn',
#  'operating profit eur mn eur mn',
#  'order intake grew year year year year respectively eur million eur billion respective january september july september period',
#  'order received grew year year eur',
#  'orion pharma operating profit increased',
#  'passenger volume rose accounting period',
#  'passenger related revenue rose eur mn eur mn',
#  'pretax profit rose eur mn eur mn corresponding period',
#  'pretax profit rose eur mn eur corresponding period',
#  'pretax profit rose eur mn eur mn',
#  'pre tax profit totaled eur mn eur mn',
#  'profit period totaled eur mn eur mn corresponding period',
#  'profit period eur mn eur mn',
#  'profit period eur mn eur mn',
#  'revenue grew percent x ac billion u billion',
#  'revenue july september grew percent euro million year earlier company said thursday',
#  'revenue time grew percent million euro',
#  'sale latin america increased eur mn total mn mobile device sold area representing increase corresponding period',
#  'sanoma magazine finland net sale grew eur mn eur mn',
#  'satama net profit third quarter rose euro euro period',
#  'section regional news demand finnair asian traffic measured passenger kilometer august compare last year',
#  'svyturys utenos alus controlled nordic group baltic beverage holding bbh posted percent growth beer sale january september million liter',
#  'would increase estimated sale million last year',
#  'chain posted sale million euro full rise percent year year',
#  'company expects net sale increase',
#  'company operating income ebit totalled eur mn eur mn year year',
#  'eps outlook increased pct pct',
#  'fair value investment property totaled eur mn eur mn',
#  'finnish government announced wednesday sold percent stake chemical fertilizer group kemira oyj x ac million u million sending company share price percent',
#  'helsinki based company also owns salomon atomic suunto brand said net profit rose percent three month dec x ac million u million x ac million year earlier',
#  'operating profit grain trading increased eur mn eur mn',
#  'stock rose second day wednesday bringing two day rise gbx',
#  'stock rose third day tuesday bringing three day rise gbx',
#  'transaction would increase earnings per share first quarter eur',
#  'total operating revenue grew year year eur',
#  'vacon cash flow operation grew eur mn eur mn year ago',
#  'basware product sale grew strongly financial period percent',
#  'february finnish textile clothing company marimekko oyj hel mmo v said today preliminary operating profit grew eur eur',
#  'affecto expects net sale whole increase level reached eur million',
#  'cash flow operation rose eur mn eur mn',
#  'commission income rose eur mn eur mn',
#  'earnings per share january june eur increase year year eur',
#  'earnings per share eps rose eur eur',
#  'elisa said mobile subscription grew percent mainly customer adopting called third generation mobile technology',
#  'eps quarter came eur eur year ago ahead forecast eur',
#  'eps grew eur eur',
#  'export grew percent million liter',
#  'finnish investment group panostaja oyj said net profit went mln euro mln fiscal ended october mln euro mln period fiscal',
#  'finnish metal component supplier componenta oyj said net profit went mln euro mln mln euro mln',
#  'finnish silicon wafer technology company okmetic oyj omx helsinki okm v reported thursday october operating profit eur january september eur corresponding period',
#  'fiskars brand report net sale eur mn eur mn',
#  'however proportion paid standing order grew',
#  'january september group net sale continuing operation rose eur mn eur mn corresponding period',
#  'july september yit net sale increased eur mn compared eur mn corresponding period',
#  'reporting period net sale rose year year eur due business acquisition realized first half effect eur review period',
#  'reporting period company operating profit grew eur million',
#  'last year net sale rose eur million eur million',
#  'last year company raised turnover approximately million litas eur mln million litas',
#  'marimekko group full year net sale estimated increase',
#  'net sale surged eur million',
#  'nevertheless market share rose percent percent year earlier',
#  'october december sale mln eur pct increase year year',
#  'olvi control percent stake ragutis le coq said annual report published earlier year lithuanian brewery sale reached million euro last year rise percent million euro',
#  'olvi expects sale market share increase first quarter',
#  'operating profit increased eur mn eur mn corresponding period',
#  'operating profit asian plant grew markedly',
#  'operating profit totaled eur mn eur mn',
#  'operating profit totalled eur mn eur mn year year',
#  'production capacity increase tonne per year raw material continue recycled paper board',
#  'profit period increased eur mn eur mn',
#  'profit per share eur eur',
#  'return capital employed rose percentage point',
#  'revenue july september grew percent euro billion finnish company said thursday',
#  'revenue grew percent euro million u million euro million',
#  'ruukki order book end year year quarter quarter',
#  'sale finland rose international growth',
#  'sale security system packaging increased slightly',
#  'stora enso third quarter pre tax profit doubled eur mn',
#  'company market share continued increase',
#  'company scheduled traffic measured revenue passenger kilometre rpk grew nearly passenger carried scheduled flight february',
#  'disposal autotank also strengthen aspo capital structure commented gustav nyberg ceo aspo',
#  'earnings per share quarter came eur eur quarter year earlier',
#  'economic occupancy rate sponda property portfolio rose',
#  'group month operating profit grew percent million euro',
#  'growth net sale first half compared first half',
#  'pretax profit group life insurance business increased eur million eur million',
#  'pretax profit group life insurance business increased eur eur',
#  'total delivery volume paper business tonne tonne',
#  'value firm forestry holding increased sek bn',
#  'turnover rose eur eur',
#  'finnish talvivaara mining co hel tlv v said thursday picked bofa merrill lynch jpmorgan nyse jpm joint bookrunners planned issue convertible note worth eur usd',
#  'mall part baltic pearl development project city st petersburg baltic pearl cjsc subsidiary shanghai foreign joint investment company developing home people',
#  'complete name shareholder otto henrik bernhard nyberg information amount share transferred corresponds total number share aspo plc',
#  'data processing unit collect data calculates rvr value provides data user via various interface',
#  'german commerzbank ag hamburg branch u jp morgan nyse jpm participated arranger dutch ing am inga co arranger',
#  'increase number share based option right granted management company stock option plan',
#  'office worldwide pct net sale generated outside finland',
#  'nokia messaging enables customer receive e mail e mail account mobile phone supporting pop imap e mail service',
#  'contract value amount eur company added',
#  'aldata said still number operational aspect defined microsoft detail product market initiative resulting agreement available later date',
#  'alexandria va may kenneth bower vista calif developed ornamental design handset u patent trademark office announced',
#  'biohit oyj develops manufacture market liquid handling product diagnostic test system use research healthcare industrial laboratory',
#  'mr ashley deputy executive chairman sport direct sold pc stake company pound time float',
#  'rental building equipment accounted percent operating income',
#  'ruukki delivery includes steel structure including installation krakeroy bascule bridge steel pile bridge foundation',
#  'stockmann established finland became first foreign company enter russia retail trade market',
#  'broad based wig index ended thursday session pct pt blue chip wig pt',
#  'business divested generates consolidated net sale eur million annually currently employee',
#  'company generates net sale mln euro mln annually employ',
#  'contract cover manufacturing surface treatment installation steel structure',
#  'order also includes start commissioning service',
#  'phone targeted first time user growth market',
#  'tielinja generated net sale mln euro mln',
#  'tikkurila powder coating employee four paint plant generated revenue eur usd',
#  'rental agreement stockmann committed invest building bridge gogol street build underground tunnel crossing street',
#  'vnh generates annual net sale mln eur employ people',
#  'jan ford struggling face slowing truck suv sale surfeit date gotta car',
#  'pharmaceutical group orion corp reported fall third quarter earnings hit larger expenditure r marketing',
#  'however growth margin slowed due financial crisis',
#  'helsinki afx nokian tyre reported fourth quarter pretax profit mln eur mln back strong sale',
#  'kalnapilio tauro grupe kalnapilis tauras group owned denmark royal unibrew raised market share percent percent beer sale seven month jumped percent million liter',
#  'company estimate net sale increase considerably operating result clearly positive',
#  'uponor made operating profit eur mn eur mn made record year',
#  'basware corporation stock exchange release august basware signed large deal international industrial group basware deliver invoice automation solution connectivity service international industrial group',
#  'estimate operating profit improve third quarter',
#  'ruukki forecast annual sale growth positive pretax result',
#  'sale rose pct mln eur back strong volume favourable currency effect',
#  'growth net sale continued favourably middle east africaand asia pacific',
#  'appointment kaupthing bank aim co ordinate capital market activity within group improve overall service client',
#  'following increase huhtamaki registered share capital eur number share outstanding',
#  'helsinki october ssh communication security corp board director information please contact tomi laamanen chairman tel distribution nasdaq omx helsinki ltd',
#  'offer million share aimed raise x ac million u million expected completed oct outokumpu said',
#  'theodosopoulos said tellabs could value nokia siemens nortel given leading supply status verizon along high growth product',
#  'succeeded increasing market share sold apartment comment mr kari kauniskangas head yit international construction service',
#  'capman partner able develop business continue focus providing quality restaurant service customer say christopher wynne ceo papa john russia',
#  'finnish suominen corporation specialises wet wipe nonwovens flexible packaging report net sale eur mn second quarter eur mn second quarter',
#  'finnish telecom software developer tecnomen oyj said december mln mln euro order supply expansion charging messaging system mobile fixed network brasil telecom',
#  'bank see potential getinge share rise',
#  'company recorded revenue e million fiscal year ended december increase',
#  'robust growth result inclusion clothing chain lindex group december',
#  'six brewery recorded percent growth domestic beer sale last year million liter million liter sold',
#  'january ephc board director approved increase quarterly dividend per share',
#  'bilfinger investor cheered agreement pushing share euro euro afternoon trade',
#  'london afx share rautaruukki corp upgraded hold sell abn amro price target raised eur said dealer',
#  'london marketwatch nokia nok said five year service contract run hutchison essar network operation nine location india',
#  'progress group qpr representative saudi arabia north africa signed framework agreement long term strategic relationship ise',
#  'ragutis controlled finnish brewery olvi achieved percent rise beer sale million liter held percent market share',
#  'addition cramo peab signed exclusive five year rental agreement finland extended existing rental agreement swedish market another five year',
#  'outotec oyj press release december outotec establishes new subsidiary kolkata outotec established subsidiary india order better serve indian customer increase business growing indian market',
#  'original contract signed last summer',
#  'number collection error fell considerably operation speeded',
#  'second quarter group pretax loss narrowed eur eur',
#  'january finnish metal product company componenta oyj hel cth v said yesterday net loss narrowed eur last quarter eur period year earlier',
#  'may finnish liquid handling product diagnostic test system maker biohit oyj hel biobv said today may net loss narrowed eur usd first quarter eur period',
#  'finnish metal product company componenta oyj hel cth v said today net loss narrowed eur usd last quarter eur million period year earlier',
#  'finnish steel maker rautaruukki oyj hel rtrks ruukki said today net loss contracted eur million usd first nine month eur million period year ago',
#  'first nine month talvivaara net loss narrowed eur million eur million period',
#  'first nine month company net loss narrowed eur eur million corresponding period',
#  'first nine month company net loss narrowed eur eur corresponding period',
#  'adp news feb finnish computer service company proha oyj hel art v said today net loss narrowed eur usd eur million',
#  'new factory working model reorganisation would decrease nokian tyre cost factory eur million usd',
#  'october finnish metal product company componenta oyj hel cth v said yesterday net loss narrowed eur first nine month eur period',
#  'finnish fiber plastic product maker suominen corporation said net loss narrowed mln euro mln first nine month mln euro mln period',
#  'second quarter raute net loss narrowed eur eur million period',
#  'metsaliitto however narrowed net loss second quarter mln euro mln mln euro mln year ago',
#  'narrow eur mo october finnish software hardware developer elektrobit oyj hel ebg v eb said today net loss narrowed eur first nine month eur period year ago',
#  'diluted loss per share narrowed eur eur',
#  'unit cost flight operation fell percent',
#  'loss third quarter eur mn smaller loss second quarter',
#  'february finland based steel maker rautaruukki oyj hel rtrks ruukki said today slipped larger expected pretax loss eur fourth quarter year earlier profit eur',
#  'result tax decreased nearly eur mn compared nearly eur mn previous accounting period',
#  'company slipped operating loss eur million profit eur million',
#  'april finnish construction engineering company outotec oyj hel ote v said today slipped net loss eur first quarter net profit eur corresponding period last year',
#  'cramo slipped pretax loss eur million pretax profit eur million',
#  'finnish solution provider affecto oyj hel afe v said today slipped net loss eur usd second quarter profit eur corresponding period year earlier',
#  'comptel slipped net loss eur profit eur previous year',
#  'q profit tax amounted eur mn eur mn q',
#  'adpnews feb finnish real estate investor sponda oyj hel sda v said today slipped net loss eur million usd profit eur million',
#  'profit tax amounted eur mn eur mn year ago',
#  'profit tax decreased eur mn first nine month compared eur mn year earlier',
#  'profit tax decreased eur mn eur mn year',
#  'profit tax eur mn eur mn',
#  'company profit tax fell eur mn third quarter compared eur mn corresponding period',
#  'august october company result tax totalled eur mn eur mn corresponding period',
#  'finnish bore owned rettig family grown recently acquisition smaller shipping company',
#  'plan estimated generate eur million usd cost saving annual basis',
#  'finnish pharmaceutical company orion report profit tax eur mn third quarter eur mn corresponding period',
#  'finnish sampo bank danish danske bank group report profit tax eur mn eur mn',
#  'profit tax period eur eur last year',
#  'profit tax eur mn eur mn year earlier',
#  'august finnish measuring equipment maker vaisala oyj hel vaias said today net loss widened eur first half eur corresponding period year earlier',
#  'finnish power supply solution system provider efore oyj said net loss widened mln euro mln first quarter fiscal ending october euro mln period fiscal',
#  'elcoteq group recently announced last three month previous year brought major loss half billion kroon eur mln fifth quarter running',
#  'current year raute expects net sale increase operating result positive',
#  'turnover surged eur eur due increasing service demand especially third quarter overall growth business',
#  'result company currently anticipates net sale increase operating result positive',
#  'upm delivery increased third quarter percent efficiency operation improved chief executive jussi pesonen said',
#  'global sport equipment maker amer sport corp whose brand include atomic salomon wilson saw percent increase third quarter net profit euro million million strong sale cost cut',
#  'due rapid expansion market share tallink term passenger carriage tallinna sadam port tallinn totaled percent november percent november',
#  'cash flow operation recent quarter also reached eight year low',
#  'earnings per share eps amounted eur loss eur',
#  'earnings per share eps eur loss eur',
#  'operating profit totalled eur mn operating loss eur mn year year',
#  'operating profit totalled eur mn loss eur mn second quarter',
#  'operating result including non recurring item rose eur mn loss eur mn',
#  'tiimari finnish retailer reported geenrated quarterly revenue totalling eur mn th quarter eur mn loss',
#  'earnings per share eps amounted eur loss eur',
#  'operating profit totalled eur mn loss eur mn fourth quarter',
#  'operating profit eur mn loss eur mn year earlier',
#  'investment operational change enable additional optimisation working hour thereby cost saving',
#  'shareholder full name id code petri ailus born information please contact isto hantila ceo tel',
#  'september finnish stationery gift retailer tiimari hel tii v said today net sale rose year year eur august driven growth finland demand baltic remained weak',
#  'cet monday share bavarian nordic climbed dkk stock exchange copenhagen lost past month',
#  'example net sale increased first quarter ebitda increased negative eur mn first quarter',
#  'growth rate paying national debt extremely painful',
#  'customer satisfied basware invoice automation solution extends implementation new geography',
#  'separating side business able faster expand develop tapro retail network',
#  'according viking line managing director nil erik eklund company board director satisfied viking line performance',
#  'combining deep domain expertise application service management asm outsourcing service offering proved winning combination',
#  'finnish construction company yit oyj said november mln euro mln contract construct new office building local property company tapiola real estate oy',
#  'major order india comptel corporation received significant long term order mediation provisioning solution used leading operator india',
#  'olvi posted strong set figure first six month year',
#  'operating profit improved eur mn eur mn',
#  'standardised service met positive reception among customer well itella',
#  'performance second half exceeded expectation',
#  'ponsse project forest machine market improve expected previous year',
#  'ragutis based lithuania second largest city kaunas boosted sale last year per cent million liter',
#  'raisio bid buy glisten win win deal company chairman uk snack firm told food today february',
#  'aim annual improvement ruukki construction operating profit eur million usd starting',
#  'transaction positive impact around eur earnings ruukki recognize fourth quarter year',
#  'combined activity create value shareholder good employee customer',
#  'trend sport leisure market favorable first month year',
#  'january finnish solution provider affecto oyj hel afe v said today eur usd contract state owned lithuanian social insurance institution sodra',
#  'finnish construction group lemmink inen awarded two road building contract lithuanian transport administration',
#  'finnish flexible packaging manufacturer suominen corporation report net sale eur mn first quarter compared eur mn year earlier',
#  'finnish metso paper awarded contract rebuild sabah forest industry sfi pulp mill sabah malaysia',
#  'finnish outokumpu technology awarded several new grinding technology contract',
#  'finnish rautaruukki awarded contract supply install steel superstructure partihallsf rbindelsen bridge gothenburg sweden',
#  'according atrium president ceo matti tikkakoski company swedish operation significantly improved first quarter',
#  'according nordic financial group nordea analyst sami sarkamies make nokia portfolio competitive',
#  'arvo vuorenmaa loviisa plant general manager said application new licence standard procedure quite confident approval granted',
#  'basware ceo ilkka sihvo comment conjunction interim report whole basware succeeded well second quarter',
#  'cision say sale return u k operation profitability',
#  'citigroup inc nyse c announced global transaction service gts business awarded new mandate finland based pohjola bank group',
#  'department store sale improved eur mn',
#  'finland national carrier finnair plc carried record million passenger increase percent previous year airline reported tuesday',
#  'finnair plc carried record million passenger increase percent previous year finnish national carrier reported tuesday',
#  'finnish consulting engineering group poyry plc omx helsinki poy said wednesday october awarded contract tanqia dibba fzc owner engineer wastewater system dibba emirate fujairah uae',
#  'finnish handling system company cargotec oyj hel cgcbv said today eur million usd contract deliver macgregor hatch cover ship ordered norwegian shipowner grieg shipping',
#  'finnish steel maker rautaruukki oyj ruukki said july mln euro mln contract supply install steel superstructure partihallsforbindelsen bridge project gothenburg western sweden',
#  'however broker gave outperform recommendation stock',
#  'last year sysopen digia invested ibm product know building portal trading place system successfully implemented customer solution supported',
#  'outotec net profit second quarter jumped mln euro mln mln euro mln year ago',
#  'pretax profit jumped eur million eur million',
#  'profitability ebit compared previous year period',
#  'sale improved sek mn compared sek mn',
#  'savon koulutuskuntayhtyma finland based company awarded contract specialist agricultural forestry machinery',
#  'skf april alandsbanken given buy recommendation swedish industrial company skf ab sto skf b share price target sek',
#  'sport equipment sale also progressed well owing prolonged winter season',
#  'tele affarsvarlden gave buy recommendation mobile operator tele ab share price target crown euro',
#  'acquisition immediate positive impact aspocomp financial result',
#  'australian company mirabela nickel awarded outokumpu technology contract grinding technology nickel sulfide project bahia state brazil',
#  'company also said poland profitability program launched oborniki steel frame sandwich panel plant',
#  'group also strong global position fishing category',
#  'original name componenta l subsidiary finnish componenta group changed l component company seen growth q comparison q',
#  'resulted improved sale figure sweden',
#  'upm kymmene upgraded line underperform goldman sachs',
#  'demand sport equipment good',
#  'finlan listed food industry company hkscan group controlled company baltic improved revenue eur mn eur mn eur mn year',
#  'finnish airline finnair deal uk public sector official airline flight london heathrow osaka japan well flight manchester uk helsinki finland',
#  'finnish cargotec kalmar received significant order u department defense',
#  'cargotec germany gmbh awarded contract stadtverwaltung mainz chassis body open procedure',
#  'earnings per share quarter also higher year year eur versus market expectation eur',
#  'ebitda year improved eur compared eur',
#  'finnish construction group lemminkainen oyj hel lem said today contract provide technical service nevsky centre shopping mall opened november st petersburg russia',
#  'finnish software developer basware oyj said november u subsidiary basware inc order provide software contract lifecycle management unnamed u medical technology company',
#  'however sale volume food industry expected remain relatively good level finland scandinavia atrium said',
#  'nordea see return positive growth baltic country',
#  'operating profit improved eur mn',
#  'operating profit improved eur mn eur mn',
#  'operating profit improved er mn eur mn',
#  'operating profit improved eur mn eur mn',
#  'previously company anticipated operating profit improve period',
#  'productional situation improved',
#  'rautaruukki said construction group yit awarded mln eur contract supply steel structure new bridge spanning kemijoki river northern finland',
#  'sale came mln eur compared mln also beating consensus forecast mln eur',
#  'thanks multiplying effect wagon performance transport much efficient say development manager juha malkia vr cargo',
#  'company make garden tool scissors consumer good said earnings boosted mln eur income received pct shareholding finnish engineering group wartsila',
#  'company anticipates turnover whole surpass previous year eur million',
#  'eps improved eur eur',
#  'financial impact estimated annual improvement eur division result fiscal year',
#  'financial impact estimated meur annual improvement division result starting fiscal year',
#  'rationalization operation seek achieve eur million yearly saving second quarter current financial year',
#  'sale result gain eur million second quarter oriola kd support finnish company strategy focus pharmaceutical wholesale retail operation',
#  'turun kaupunkin finland based company awarded contract lemminkainen talotekniikka oy electrical installation work',
#  'moderate significant change resulted significant reduction estimated cvd risk',
#  'uponor improved performance spite decrease residential construction u',
#  'simultaneously responsibility area extended legal affair cover also merger acquisition',
#  'plant ground continue grow success garden lie well maintained',
#  'poyry contract includes engineering management civil detail engineering service time scheduling procurement service',
#  'addus service include personal care assistance activity daily living skilled nursing rehabilitative therapy adult day care',
#  'aldata solution oyj bertrand sciard president ceo information aldata solution oyj bertrand sciard president ceo tel aldata retail wholesale aldata business dedicated retail wholesale business improvement',
#  'alfa group voting stock new company telenor free float',
#  'altogether subject mildly elevated cholesterol level participated four month long intervention',
#  'arto ryymin born replace juhani kaisanlahti worked acting evp healthcare welfare since august',
#  'capman haavisto responsible group finance accounting',
#  'cablevision system corp cvc madison square garden division owns operates new york knickerbockers basketball team also madison square garden arena new york ranger hockey team new york liberty woman basketball team hartford wolf pack hockey team',
#  'capman six investment area capman buyout capman technology capman life science capman russia capman public market capman real estate dedicated team fund',
#  'capman plc press release march jukka ruuska president omx nordic exchange stockholm stock exchange transfer capman effective no later september',
#  'cent profile contains business operation company history major product service prospect key competitor structure key employee location subsidiary',
#  'conference call participate via conference call please dial minute beginning event europe usa',
#  'construction scheduled start april june completed early',
#  'founded strand associate provides civil environmental transportation electrical mechanical engineering service employee office wisconsin alabama illinois indiana kentucky ohio',
#  'halonen office acknowledged receiving letter declined comment',
#  'headquartered city company nearly year old focus science based innovation technology environmental measurement',
#  'lee man combined annual production capacity close million tonne paper tonne pulp',
#  'method smelt spout separated working area shielding wall arranged movable relation smelt spout',
#  'necessary strengthen company operation however',
#  'le lay succeeds walter g nter based finland',
#  'lemminkainen infra oy subsidiary lemminkainen sverige ab perform construction work expected start early completed summer',
#  'los angeles based pacific office property trust acquires owns operates office property western u focusing initially market honolulu san diego los angeles phoenix',
#  'mr mikko saavalainen head comptel global sale concludes gibtelecom provides perfect illustration variety business technical regulatory challenge operator facing os today',
#  'professional consumer application include personal navigation personal safety field workflow management asset tracking',
#  'satama trainer house remain name independent brand business area',
#  'mentioned shareholder suggest monthly salary eur would paid board member outside company',
#  'address location provided local controller preferably wireless transmission us address location access appliance control module',
#  'bank also examining benefit transferring swedish business operate branch office operation would governed finland law',
#  'donation granted aalto university university helsinki tampere turku eastern finland jyv skyl oulu vaasa polytechnic announced later',
#  'guidance set basis point mid swap report said',
#  'invention carry international patent publication no',
#  'inventor bylander johan ponten fredrik lundberg jorgen',
#  'inventor mukkavilli krishna kiran sabharwal ashutosh aazhang behnaam',
#  'inventor ridge justin bao yiliang karczewicz marta',
#  'issuer solely responsible content announcement',
#  'market making accordance agreement begin september',
#  'offer price million including cash million net debt assumption face million worth cencorp share issued savcor',
#  'original patent filed finland application no',
#  'swedish subsidiary hold net smelter return nsr royalty two advanced copper project northern sweden viscaria adak project developed avalon mineral ltd asx avi',
#  'total investment vantaa plant extension amount around million euro okmetic share investment worth around million',
#  'need ready window open rosberg said',
#  'issue identified stonesoft affect range content inspection technology',
#  'want credit card info personal detail',
#  'dopplr dopplr service smart traveller',
#  'according sweden minister local government financial market mat odell decision sell state share telecom group teliasonera carried cooperation state finland',
#  'according capman plc corporate governance majority committee member shall independent company',
#  'according finnair technical service measure due employment situation',
#  'according honka japan managing director marko saarelainen honkarakenne export ready made log house japan year',
#  'according preliminary data slovakia statistic office good worth e million imported finland january october making percent slovakia total import',
#  'according seikku retail sector finland controlled large actor food manufacturer still relatively small',
#  'also six year historic analysis provided market',
#  'also six year historic analysis provided market',
#  'amanda said already made usd investment commitment russia partner ii fund july',
#  'invention released patent office said chamber pressurized',
#  'audio webcast available live archived cerner web site www cerner com',
#  'basware order matching automatically match purchase invoice approved purchase order',
#  'capacity facility made finland vaahto group ton light coated paper',
#  'capman asset manager eur bn worth asset management nordic region',
#  'capman four investment area capman buyout capman technology capman life science capman real estate dedicated team',
#  'castecka said town hall would hold talk investor interested zone',
#  'change announced today effective close trading friday june',
#  'chs expo freight major finnish fair exhibition culture logistics company provides logistics service various event land air sea',
#  'competition authority approve deal finalized',
#  'complete name shareholder otto henrik bernhard nyberg information please contact maija liisa friman ceo tel',
#  'completion transaction subject final agreement due diligence process',
#  'construction expected completed summer',
#  'dragonfly love another video shot start finish using nokia n',
#  'elcoteq electronics manufacturing service em business segment serf customer globally engineering manufacturing fulfillment service',
#  'eqt completed exit salcomp finnish company make mobile phone charger selling remaining stake swedish investment group nordstjernan euro million million',
#  'financialwire tm cooperation investrend broadcast syndicate also provides complete daily conference call webcast schedule service shareholder investor via firstalert tm network oefirstalert tm daily',
#  'following registration number issued outstanding share basware',
#  'fortum previously bought state held stake tgk rao ues reform',
#  'goodwill intangible asset account mln euro mln purchase price pct payable aspo share',
#  'harold w young independent broker working closely several retailer including ahold usa market basket cv bj wholesale club hannaford cumberland farm',
# ...
#  'sale expected increase end year however',
#  'satama net sale would higher year',
#  'systeemitiimi sale project resource also strengthened director paul skogberg said',
#  'action expected deliver annual cost saving eur',
#  'company well positioned brazil uruguay',
#  'company report loss period eur mn compared loss eur mn corresponding period',
#  'company turned earnings per share eps eur versus loss per share eur',
#  'fourth quarter saw rapala swing back pretax profit mln eur year earlier loss mln back pct uplift sale mln eur stronger performance north america',
#  'soapstone deposit medvezhyegorsk area expected increase tulikivi current reserve considerably',
#  'measure expected produce annual cost saving eur million starting',
#  'bring cost saving eur mn year',
#  'via move company aim annual saving eur main part expected realized year',
#  'july finnish steel maker rautaruukki oyj hel rtrks ruukki said today turned net profit eur second quarter net loss eur corresponding period last year',
#  'october finnish wood product technology supplier raute oyj hel rutav said today swung net profit eur first nine month versus net loss eur period year earlier',
#  'february finnish broadband data communication system provider teleste oyj hel tlt v said yesterday net profit rocketed eur eur lifted dividend proposal',
#  'february finnish broadband data communication system provider teleste oyj hel tlt v said wednesday net profit rocketed eur eur lifted dividend proposal',
#  'cargotec corporation press release august finnish time cargotec macgregor business area providing marine cargo handling offshore load handling solution received significant offshore crane retrofit order',
#  'ebit totalled eur mn compared loss eur mn corresponding period',
#  'finnish broadband data communication system provider teleste oyj hel tlt v said yesterday returned net profit eur million usd first nine month versus net loss eur period',
#  'finnish consumer packaging manufacturer huhtamaki oyj said swung net profit mln euro mln first nine month net loss mln euro mln period',
#  'finnish dental care group oral hammaslaakarit oyj posted total net profit euro mln first nine month versus net loss euro period',
#  'finnish consultancy satama interactive oyj posted net profit mln euro mln first nine month compared net loss euro period',
#  'finnish pulp paper machinery maker vaahto group oyj swung mln euro mln net profit fiscal ended august euro net loss fiscal',
#  'finnish silicon wafer manufacturer okmetic oyj said swung net profit mln euro mln first nine month net loss mln euro mln year earlier',
#  'second quarter company net profit eur compared net loss eur april june',
#  'therefore seems finnish shipping company viking line get subsidy need order new lng fuelled vessel',
#  'jarmo honkamaa head oil refining business neste oil say situation look promising viewpoint',
#  'mformation nokia noted established interoperability agreement cover commercially proven standard based management mobile device well mobile device security mobile application management',
#  'mn pretax profit eur mn eur mn third quarter',
#  'net sale however increase',
#  'operating profit totaled eur mn compared eur mn corresponding period',
#  'profit tax eur mn compared eur mn previous year',
#  'profit period eur mn compared eur mn',
#  'quarterly diluted eps continuing operation came eur compared last year eur',
#  'raute posted net profit mln euro mln third quarter compared net loss euro corresponding period',
#  'return equity stood compared third quarter',
#  'russian export duty activate harvesting finland sale russia increase also',
#  'company expects net sale significantly increase',
#  'company net profit amounted ee mn',
#  'optimization steel component heating process reduce energy consumption',
#  'new partnership agreement represents significant milestone party',
#  'tiimari latvian representative ineta zaharova said company earned lvl profit time',
#  'inge larsen cfo share representing share capital',
#  'forecast',
#  'share capital alma medium corporation business id eur divided share',
#  'company listed nordic exchange helsinki',
#  'incap contract manufacturing carry manufacturing agreement factory tumkur near bangalore',
#  'operated nokia supported nokia netact network service management system',
#  'comptel corporation publish financial statement february',
#  'shop located capital region paijat hame region',
#  'annual net sale unit eur million currently employ people',
#  'following workday customer check home computer purchase divided different ingredient group much energy various product contain nutritional content purchase',
#  'name company holding acquired citycon oyj',
#  'basware headquartered espoo finland',
#  'store located poznan shopping center named pestka company added',
#  'seat would go edgar edmonds american experience clothing retail industry christian fischer austrian experience winter sport good business',
#  'ahlstrom employee serve customer via sale office production facility country six continent',
#  'raute headquartered nastola finland technology company serving wood product industry worldwide',
#  'according latest information benefon launch twig device september',
#  'report capman plc ceo heikki westerlund',
#  'price specified completion date',
#  'total million invested project',
#  'finnish consultancy satama interactive oyj said november jarmo lonnfors took position ceo',
#  'nordea definitely big sampo acquire said analyst sampo would appear agenda nordea ahead privatisation',
#  'could',
#  'p central office nordea bank ya ulitsa yamskogo polya building telephone ext unimilk egm xvi international business summit food business russia take place',
#  'share still subscribed series e share option max',
#  'new share option right plan packaging company huhtamaki oyj reported monday total new share company issued based share subscription option right plan',
#  'meeting medium analyst held day stonesoft headquarters helsinki italahdenkatu interim report presented stonesoft ceo ilkka hiidenheimo',
#  'meeting glisten shareholder vote bid held march',
#  'replay available october following number u caller non u caller access code',
#  'came aspo chemical aspo shipping aspo system',
#  'evraz group share owned lanebrook whose beneficiary one hand millhouse holding company asset billionaire roman abramovich business partner evraz executive alexander abramov alexander frolov',
#  'aker yard finland begin using chinese subcontractor finnish shipyard',
#  'finnish food industry company l nnen tehtaat planning change fish product business',
#  'according business medium report usmanov planned transfer megafon stake state controlled svyazinvest exchange stake merged rostelecom',
#  'according gallup food farm fact beef consumption totaled mn kilo finland',
#  'according company decision issue made summer earliest summer latest',
#  'according finnish russian chamber commerce major construction company finland operating russia',
#  'according notification holding ameriprice inc group company total share represent tekla share voting right',
#  'sale savcor group ltd comprise savcor art corporate function investment cencorp corporation',
#  'ahlstrom share quoted nasdaq omx helsinki',
#  'yit capital market day material available company internet site www yitgroup com investor september',
#  'alma medium hold company remaining share owned company key employee',
#  'almost entire office building occupied metso',
#  'also development online business continue',
#  'part agreement employee john deere forestry documentation function transfer dokumentori oy',
#  'alternative share exchange panostaja offer full cash consideration value euro per share',
#  'eet alma medium annual report scheduled published calendar week',
#  'end august sampo nordea biggest shareholder stake followed state',
#  'first solteq service company operating st petersburg area include maintenance material management system data collection solution',
#  'autotank group part aspo system division',
#  'fki john jiang worked several general manager senior business consultant position international company china',
#  'bid offer include least share value share must correspond least eur',
#  'capman said deal effect cash flow total eur transaction would not affect financial result executed fair value',
#  'catalyst segment includes refinery catalyst polyolefin catalyst product category',
#  'componenta metal sector company international operation production plant located finland netherlands sweden turkey',
#  'consisting seven interconnected unit mega image logistics center metre length metre height',
#  'construction work helsinki music centre start autumn total cost project estimated million euro',
#  'cramo headquartered vantaa finland rent construction machinery equipment well rent sell modular space',
#  'currency conversion based exchange rate time deal',
#  'currently terminator lure produced subcontract facility mexico manufacturing transferred rapala factory shenzhen china',
#  'destia oy finnish infrastructure construction service company building maintaining designing traffic route industrial traffic environment also complete living environment',
#  'digia also set two subsidiary digia norway digia usa inc',
#  'share entitled one vote',
#  'year dividend deducted subscription price',
#  'earnings per share eps amounted eur',
#  'elcoteq global network market service site long experience serving consumer electronics system solution customer',
#  'elcoteq se listed nasdaq omx helsinki ltd',
#  'electronic version require hour copy customized client digital control custom watermark',
#  'elisa corporation disclose financial statement thursday february',
#  'erkki jarvinen president rautakirja head sanoma trade division leave current task spring similar position outside sanoma group',
#  'ethanol would made barley production could start',
#  'exel composite brief exel composite technology company design manufacture market composite profile tube industrial application',
#  'exel headquartered mantyharju finland',
#  'financial statement include consolidated financial statement group board director report auditor report corporate governance statement',
#  'financialwire tm not press release service receives no compensation news opinion distribution',
#  'finnish bank land launch long term pension saving account beginning june',
#  'finnish sampo rosenlew manufacture approximately seven forest machine monthly half machine exported',
#  'finnlines six ship construction china delivery scheduled first quarter final quarter',
#  'finnlines announce week measure take tackle situation',
#  'following issue new share constitute percent firm capital',
#  'founded finnair one world oldest airline fly destination fleet aircraft employing people',
#  'glaston share gla v listed nasdaq omx helsinki mid cap list',
#  'ground notification tiimari plc issued capital convertible loan allocation decision board',
#  'gypsii service support ten different language including korean russian',
#  'confirmed view july',
#  'however offering probably not made current valuation partly derives deal company merged stock market shell',
#  'huhtamaki oyj stock exchange release huhtamaki capital market day institutional investor analyst held espoo september starting pm finnish time',
#  'honkarakenne start production need partner sawmill operation',
#  'addition tulikivi corporation also currently member board following company altia corporation j rvi suomen portti osuuskunta osuuskunta kpy profile vehicle oy voimatel oy',
#  'future plant focus production flange profile wind farm tower',
#  'incap corporation stock exchange announcement april p invitation news conference incap interim report q incap publish interim report january march wednesday may',
#  'ionphase second major owner venture capital firm aura capital',
#  'iso omena based matinkyla district southern part city espoo southern finland',
#  'itg share deal estimated euro',
#  'customer include local company slo oy kiilto oy toptronics oy normark suomi oy pellonpaja oy mansner oy',
#  'jensen njastein mike critch head dovre north america business unit report toivola',
#  'kemira headquartered helsinki finland international chemical group comprising business area kemira pulp paper kemira water kemira specialty kemira coating',
#  'kemira partner project st petersburg water work',
#  'kone listed nordic exchange helsinki',
#  'l operative finland sweden latvia russia norway',
#  'latvia stockmann shopping mall subsidiary finland stockmann plc',
#  'leed internationally recognized green building certification system developed u green building council',
#  'china unicom nyse chu hkse shse second largest mobile carrier country',
#  'metsa botnia finance payment dividend repayment capital repurchase share fund deriving divestment uruguay operation share pohjolan voima utilising existing financing facility',
#  'metso delivery include complete coated board line related air system two winder',
#  'dividend go grimaldi family',
#  'neste shipping likely remain finnish oil sector transport significant emergency supply',
#  'no compensation news opinion distribution',
#  'no financial detail disclosed',
#  'company net sale acquired finland european country asia u',
#  'official not disclose contract value',
#  'otherwise situation control',
#  'customer come following country uk usa spain france italy germany china hong kong sweden norway netherlands austria belgium switzerland czech republic finland canada russia ukraine denmark ireland south korea liechtenstein',
#  'customer come following country uk usa spain france italy germany china sweden norway netherlands austria belgium switzerland czech republic serbia finland canada russia ukraine portugal denmark ireland south korea estonia liechtenstein',
#  'paychex office serving approximately payroll client nationwide may',
#  'payment share shall effected subscription',
#  'pc digital guatemala using tecnomen prepaid system telgua fixed network well code division multiple access cdma global system mobile communication gsm since',
#  'poyry global consulting engineering firm focusing energy forest industry infrastructure environment sector',
#  'production scheduled start end april',
#  'ramirent finland domestic unit machinery rental company ramirent oyj hel rmr v',
#  'raute listed nordic exchange helsinki',
#  'registration required',
#  'related link flexiblebaseloadoperation thewartsila generating set gasconversions shorter two version press release',
#  'rosendal outotec com eila paatela vice president corporate communication tel e mail eila',
#  'runway visual range calculated assessment distance pilot see runway',
#  'salcomp charger manufacturing plant india located nokia telecom park state tamil nadu eastern part india',
#  'saunalahti part elisa group',
#  'say brian burton head security vodafone uk',
#  'seller finnish elcoteq group largest european electronics manufacturing service company',
#  'solteq plc announcement share repurchase helsinki stock exchange solteq plc hold total share including share repurchased',
#  'recent technology delivery include refinery technology anrak aluminium iron ore pelletizing plant tata steel iron ore sintering plant bhushan steel',
#  'srv also build aqua park wellness area restaurant multifunctional ice arena',
#  'ssh communication security corporation headquartered helsinki finland',
#  'steek set based bordeaux southwestern france',
#  'stockmann plc company announcement february annual summary stockmann stock exchange financial press release available company website address www stockmann com',
#  'suomen paikallissanomat oy part alma medium group currently publishes local newspaper across finland',
#  'talvivaara listed london stock exchange main market nasdaq omx helsinki included ftse index',
#  'tecnotree convergent charging solution includes functionality prepaid post paid billing charging rating voice call video call raw data traffic mobile fixed network',
#  'teleste office worldwide listed nordic exchange helsinki',
#  'teleste set divided broadband cable network video network business area',
#  ...]

# %%
X[0]
# Out:
# 'According to Gran , the company has no plans to move all production to Russia , although that is where the company is growing '

# %% [markdown]
# ### Using Bag of Words to convert words to vector

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer(binary=True, ngram_range=(2,2))
X_new = cv.fit_transform(corpus)

# %%
X_new[0]
# Out:
# <1x28655 sparse matrix of type '<class 'numpy.int64'>'
# 	with 10 stored elements in Compressed Sparse Row format>

# %%
X_new.shape
# Out:
# (5000, 28655)

# %% [markdown]
# ### Training a RandomForest Classifier

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_new, y, test_size=0.3, random_state=42)

# %%
X_train.shape
# Out:
# (3500, 28655)

# %%
y_train.shape
# Out:
# (3500,)

# %%
#implementing RandomForest Classifier
from sklearn.ensemble import RandomForestClassifier

rnd_clf = RandomForestClassifier(n_estimators=200, criterion='entropy')
rnd_clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=200)

# %% [markdown]
# ### Model Perfomance

# %%
# Making predictions on the test set

y_pred=rnd_clf.predict(X_test)

# %%
y_pred
# Out:
# array([0, 1, 0, ..., 0, 1, 0], dtype=int64)

# %%
# Confusion matrix

from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_pred)
# Out:
# array([[1025,   13],
#        [ 249,  213]], dtype=int64)

# %%
# Getting the accuracy score

from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8253333333333334

# %%
# Getting the classification report

from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.99      0.89      1038
#            1       0.94      0.46      0.62       462
#
#     accuracy                           0.83      1500
#    macro avg       0.87      0.72      0.75      1500
# weighted avg       0.85      0.83      0.80      1500
